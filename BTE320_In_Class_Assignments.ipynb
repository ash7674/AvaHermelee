# %% [markdown]
# <a href="https://colab.research.google.com/github/ash7674/AvaHermelee/blob/main/BTE320_In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales ($): "))
rate = float(input("Enter tax rate (%): "))

COGS = 0.4 * sales
gross_profit = sales - COGS
taxes = rate * gross_profit
net = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods sold: {COGS}$")
print(f"Gross profit: {gross_profit}$")
# Out:
# Enter sales ($): 12000
# Enter tax rate (%): 4
# Sales: 12000.0$
# Cost of Goods sold: 4800.0$
# Gross profit: 7200.0$

# %%
num1 = float(input("Enter first number: "))
op = input("Choose operator: ")
num2 = float(input("Enter second number: "))

if op == "+":
    res = num1 + num2

elif op == "-":
    res = num1 - num2

elif op == "*":
    res = num1 * num2

elif op == "/":
    res = num1 / num2

elif op == "**":
  res = num1 ** num2

elif op == "//":
    res = num1 // num2

elif op == "%":
  res = num1 % num2

else:
    print("Invalid operator")

print(f"Result: {res}")
# Out:
# Enter first number: 6
# Choose operator: and
# Enter second number: 9
# Invalid operator
# Result: -3.0
